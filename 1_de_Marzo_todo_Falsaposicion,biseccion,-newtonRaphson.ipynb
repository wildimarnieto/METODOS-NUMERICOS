# %%
import math
def f(x):
    return (math.exp(-x))-x
def g(x):
    return (math.exp(-x))
i=0
x=0
xa=0
x1=0
valor_e=0.56714329041
error_relativo_p=0
error_soportado=0
error_relativo_p2=0
error_soportado2=0
error_verdadero2=0
print'|{0:4} |  {1:20}| {2:20}| {3:20}|'.format(" ","M punto fijo","","M Newton Rapshon","")
while(i<=200):
    if x>0:
            error_verdadero=valor_e-x
            error_relativo_p=(error_verdadero/x)*100
            error_verdadero2=valor_e-x1
            error_relativo_p2=(error_verdadero2/x1)*100
    print'|{0:4} |  {1:20}| {2:20}| {3:20}| {4:20}|'.format(i,x,error_relativo_p,x1,error_relativo_p2)
    xl=g(x)
    x+=f(x)
    i+=1
    x1 = xa - (math.exp(-xa)-xa)/(-math.exp(-xa)-1)
    xa=x1
    if x==x1: 
        print"necesito "+str(i)+" iteraciones para estabilizarse"
        break
        

def newtonraphson():
    n=1
    while n<=10:
        
        return x1
    return False
# Out:
# |     |  M punto fijo        |                     | M Newton Rapshon    |
# |   0 |                     0|                    0|                    0|                    0|
# |   1 |                   1.0|        -43.285670959|                  0.5|         13.428658082|
# |   2 |        0.367879441171|        54.1655300454|       0.566311003197|       0.146966456255|
# |   3 |        0.692200627555|       -18.0666315757|       0.567143165035|    2.21064354746e-05|
# |   4 |        0.500473500564|        13.3213426428|        0.56714329041|    3.86032920001e-11|
# |   5 |        0.606243535086|       -6.44959367197|        0.56714329041|    3.80943236472e-11|
# |   6 |        0.545395785975|        3.98747203301|        0.56714329041|    3.81138993531e-11|
# |   7 |        0.579612335503|       -2.15127324413|        0.56714329041|    3.81138993531e-11|
# |   8 |        0.560115461361|        1.25471077549|        0.56714329041|    3.81138993531e-11|
# ...
